# %%
import tensorflow as tf
import numpy as np
import plotly.graph_objects as go
import plotly.io as pio
import pandas as pd
import json
import pickle
import PointNet

from plotly.subplots import make_subplots

# %%
pio.kaleido.scope.default_width = 1200
pio.kaleido.scope.default_height = 400

def plot_training_performance(history: dict, train_accuracy_key:str, val_accuracy_key: str, title: str = "Training Performance", filename: str = ''):

    epochs = [len(history[i][train_accuracy_key]) for i in list(history.keys())]
    x = np.arange(1, max(epochs))

    fig = make_subplots(specs = [[{'secondary_y': True}]])

    for h in list(history.keys()):
        fig.add_trace(go.Scatter(
            x = x,
            y = history[h][train_accuracy_key],
            mode = 'lines',
            name = f'{h}: {train_accuracy_key}'
        ),
        secondary_y = False)

        fig.add_trace(go.Scatter(
            x = x,
            y = history[h]['loss'],
            mode = 'lines',
            name = f'{h}: training_loss'
        ),
        secondary_y = True)

        fig.add_trace(go.Scatter(
            x = x,
            y = history[h][val_accuracy_key],
            mode = 'lines',
            name = f'{h}: {val_accuracy_key}'
        ),
        secondary_y = False)

        fig.add_trace(go.Scatter(
            x = x,
            y = history[h]['val_loss'],
            mode = 'lines',
            name = f'{h}: validation_loss'
        ),
        secondary_y = True)

    fig.update_layout(
        title = title,
        xaxis_title = 'Epoch'
    )

    fig.update_yaxes(title_text = 'Accuracy', secondary_y = False)
    fig.update_yaxes(title_text = 'Loss', secondary_y = True)

    if(filename != ''): fig.write_image(f"figures/{filename}")

    fig.show()
# Out:
# /tmp/ipykernel_17214/2245365343.py:1: DeprecationWarning:
#
#
# Use of plotly.io.kaleido.scope.default_width is deprecated and support will be removed after September 2025.
# Please use plotly.io.defaults.default_width instead.
#
#
# /tmp/ipykernel_17214/2245365343.py:2: DeprecationWarning:
#
#
# Use of plotly.io.kaleido.scope.default_height is deprecated and support will be removed after September 2025.
# Please use plotly.io.defaults.default_height instead.

# %% [markdown]
# #### Hyperparameter Tuning

# %%
files = {
    'RS': "models/RS_pointnet_history.json",
    }

histories = {}
for key in files.keys():
    with open(files[key], 'r') as f:
        histories[key] = json.load(f)

plot_training_performance(histories, 'categorical_accuracy', 'val_categorical_accuracy', 'Training Performance - real data only (best epoch 50, val loss 0.41, val acc 0.85)', 'RS_pointnet_training.png')

# %%
files = {
    'SIM': "models/SIM_pointnet_history.json",
    }

histories = {}
for key in files.keys():
    with open(files[key], 'r') as f:
        histories[key] = json.load(f)

plot_training_performance(histories, 'categorical_accuracy', 'val_categorical_accuracy', 'Training Performance - simulated data only (best epoch 269, val loss 0.06, val acc 0.98)', 'SIM_pointnet_training.png')

# %%
files = {
    'AUG80': "models/AUG80_pointnet_history.json"
    }

histories = {}
for key in files.keys():
    with open(files[key], 'r') as f:
        histories[key] = json.load(f)

plot_training_performance(histories, 'categorical_accuracy', 'val_categorical_accuracy', 'Training Performance - augmented data (80% real) (best epoch 153, val loss 0.21, val acc 0.92)', 'AUG80_pointnet_training.png')

# %%
files = {
    'RS80': "models/RS80_pointnet_history.json",
    }

histories = {}
for key in files.keys():
    with open(files[key], 'r') as f:
        histories[key] = json.load(f)

plot_training_performance(histories, 'categorical_accuracy', 'val_categorical_accuracy', 'Training Performance - real data, partial set (80%) (best epoch 191, val loss 0.31, val acc 0.91)', 'RS80_pointnet_training.png')

# %%
files = {
    'AUG60': "models/AUG60_pointnet_history.json",
    }

histories = {}
for key in files.keys():
    with open(files[key], 'r') as f:
        histories[key] = json.load(f)

plot_training_performance(histories, 'categorical_accuracy', 'val_categorical_accuracy', 'Training Performance - augmented data (60% real) (best epoch 183, val loss 0.18, val acc 0.92)', 'AUG60_pointnet_training.png')

# %%
files = {
    'RS60': "models/RS60_pointnet_history.json",
    }

histories = {}
for key in files.keys():
    with open(files[key], 'r') as f:
        histories[key] = json.load(f)

plot_training_performance(histories, 'categorical_accuracy', 'val_categorical_accuracy', 'Training Performance - real data, partial set (60%) (best epoch 118, val loss 0.30, val acc 0.91)', 'RS60_pointnet_training.png')

# %%
files = {
    'AUG40': "models/AUG40_pointnet_history.json",
    }

histories = {}
for key in files.keys():
    with open(files[key], 'r') as f:
        histories[key] = json.load(f)

plot_training_performance(histories, 'categorical_accuracy', 'val_categorical_accuracy', 'Training Performance - augmented data (40% real) (best epoch 84, val loss 0.22, val acc 0.91)', 'AUG40_pointnet_training.png')

# %%
files = {
    'RS40': "models/RS40_pointnet_history.json",
    }

histories = {}
for key in files.keys():
    with open(files[key], 'r') as f:
        histories[key] = json.load(f)

plot_training_performance(histories, 'categorical_accuracy', 'val_categorical_accuracy', 'Training Performance - real data only (20%) (best epoch 85, val loss 0.31, val acc 0.90)', 'RS40_pointnet_training.png')

# %%
files = {
    'AUG20': "models/AUG20_pointnet_history.json",
    }

histories = {}
for key in files.keys():
    with open(files[key], 'r') as f:
        histories[key] = json.load(f)

plot_training_performance(histories, 'categorical_accuracy', 'val_categorical_accuracy', 'Training Performance - augmented data (20% real) (best epoch 158, val loss 0.33, val acc 0.94)', 'AUG20_pointnet_training.png')

# %%
files = {
    'RS20': "models/RS20_pointnet_history.json",
    }

histories = {}
for key in files.keys():
    with open(files[key], 'r') as f:
        histories[key] = json.load(f)

plot_training_performance(histories, 'categorical_accuracy', 'val_categorical_accuracy', 'Training Performance - real data, partial set (20%) (best epoch 123, val loss 0.31, val acc 0.94)', 'RS20_pointnet_training.png')

# %%
files = {
    'RS_PT': "models/RS_PT_tnet_history.json",
    }

histories = {}
for key in files.keys():
    with open(files[key], 'r') as f:
        histories[key] = json.load(f)

plot_training_performance(histories, 'root_mean_squared_error', 'val_root_mean_squared_error', 'Training Performance - real data, T-Net regressor (best epoch 257, val loss 0.0002, val RMSE 0.01)', 'RS_PT_tnet_training.png')

# %%
files = {
    'RS_PT': "models/RS_PT_pointnet_history.json",
    }

histories = {}
for key in files.keys():
    with open(files[key], 'r') as f:
        histories[key] = json.load(f)

plot_training_performance(histories, 'categorical_accuracy', 'val_categorical_accuracy', 'Training Performance - real data, pre-trained T-Net (best epoch 124, val loss 0.38, val acc 0.87)', 'RS_PT_pointnet_training.png')

# %% [markdown]
# #### Objective 1:  Classification Accuracy

# %%
with open('models/pc_rs.pkl', 'rb') as p:
    data = pickle.load(p)
test = data.get_raw_val_set()

model = tf.keras.models.load_model('models/final/RS_pointnet.keras')

loss, accuracy = model.evaluate(tf_val)

print(loss, accuracy)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 77ms/step - categorical_accuracy: 0.4650 - loss: 1.0934
# 1.0687522888183594 0.4747474789619446

# %%
with open('models/pc_sim.pkl', 'rb') as p:
    data = pickle.load(p)
test = data.get_val_set()

model = tf.keras.models.load_model('models/final/SIM_pointnet.keras')
loss, accuracy = model.evaluate(test)

print(loss, accuracy)
# Out:
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - categorical_accuracy: 0.8047 - loss: 0.5146
# 0.7238762974739075 0.7737500071525574
